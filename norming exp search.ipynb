# %%
from collections import Counter, defaultdict
import re

from IPython.core.display import HTML
import numpy as np
import pandas as pd
import pydub
import seaborn as sns
from tqdm.auto import tqdm
tqdm.pandas()

# %% [markdown]
# ## Prepare data

# %% [markdown]
# ### CEDICT

# %%
# !wget -O - https://www.mdbg.net/chinese/export/cedict/cedict_1_0_ts_utf-8_mdbg.txt.gz | gunzip > cedict_ts.u8
# Out:
# --2023-10-04 10:53:24--  https://www.mdbg.net/chinese/export/cedict/cedict_1_0_ts_utf-8_mdbg.txt.gz
# Resolving www.mdbg.net (www.mdbg.net)... 45.79.102.60
# Connecting to www.mdbg.net (www.mdbg.net)|45.79.102.60|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 3802936 (3.6M) [application/x-gzip]
# Saving to: ‘STDOUT’
#
# -                   100%[===================>]   3.63M  5.55MB/s    in 0.7s
#
# 2023-10-04 10:53:26 (5.55 MB/s) - written to stdout [3802936/3802936]

# %%
from cedict_utils.cedict import CedictParser
parser = CedictParser()
parser.read_file("cedict_ts.u8")
entries = parser.parse()

cedict = defaultdict(set)
for entry in entries:
    cedict[entry.simplified].add(entry.pinyin.lower().replace("u:", "v"))

# %% [markdown]
# ### AISHELL

# %%
df = pd.read_csv("train.sep.txt", header=None, engine="python")
df.columns = ["file", "pinyin", "text"]
df["file"] = df.file.str.rstrip(".wav")
df["pinyin"] = df.pinyin.str.strip()
df["text"] = df.text.str.strip()

# %% [markdown]
# ### Preprocessing

# %% [markdown]
# #### Infer underlying tones

# %%
count = 0
found_sandhi = False
pinyin_re = re.compile(r"^([a-z]+)([0-9])$")
new_pinyin_list = []

for i, row in tqdm(df.iterrows(), total=len(df)):
    if row.pinyin.strip().count(" ") != row.text.strip().count(" "):
        count += 1
        continue
        
    pinyin = row.pinyin.strip().split(" ")
    hanzi = row.text.strip().split(" ")
    
    new_pinyin = []
    for j, (pinyin_j, hanzi_j) in enumerate(zip(pinyin, hanzi)):
        segments, tone = pinyin_re.findall(pinyin_j)[0]
        cedict_j = cedict[hanzi_j]
        if tone == "2" and any(reading[:-1] == segments and reading[-1] == "3" for reading in cedict_j):
            # found_sandhi = True
            new_pinyin_j = segments + "6"
        else:
            new_pinyin_j = pinyin_j
        new_pinyin.append(new_pinyin_j)
    
    new_pinyin_list.append(" ".join(new_pinyin))
        
count
# Out:
#   0%|          | 0/63262 [00:00<?, ?it/s]
# 0

# %%
df["pinyin_underlying"] = new_pinyin_list
df["has_sandhi"] = df.pinyin != df.pinyin_underlying
df
# Out:
#               file                                             pinyin  \
# 0      SSB00050001  guang3 zhou1 nv3 da4 xue2 sheng1 deng1 shan1 s...
# 1      SSB00050002       zhun1 zhong4 ke1 xue2 gui1 lv4 de5 yao1 qiu2
# 2      SSB00050003                       qi1 lu4 wu2 ren2 shou4 piao4
# 3      SSB00050004  hei1 ke4 xuan1 bu4 zhi3 yao4 bo1 da2 mou3 yi2 ...
# 4      SSB00050005  bei3 jing1 wan4 ke1 zhong3 jing1 li3 liu2 xiao...
# ...            ...                                                ...
# 63257  SSB19560477                              qing2 ge1 dui4 chang4
# 63258  SSB19560478  da4 jia1 shi4 bu2 shi4 hui4 geng4 jing1 xi3 yi...
# 63259  SSB19560479  huan4 yi4 yu4 zheng4 lao3 han4 shi2 ji3 nian2 ...
# 63260  SSB19560480  yi4 bai3 san1 shi2 wu3 wan4 jiu3 qian1 yi1 bai...
# 63261  SSB19560481  yi1 bai3 san1 shi2 san1 wan4 san1 qian1 wu2 ba...
#
#                                               text  \
# 0          广 州 女 大 学 生 登 山 失 联 四 天 警 方 找 到 疑 似 女 尸
# 1                                尊 重 科 学 规 律 的 要 求
# 2                                      七 路 无 人 售 票
# 3                        黑 客 宣 布 只 要 拨 打 某 一 个 电 话
# 4                北 京 万 科 总 经 理 刘 肖 的 观 点 极 具 代 表 性
# ...                                            ...
# 63257                                      情 歌 对 唱
# 63258                      大 家 是 不 是 会 更 惊 喜 一 些 呢
# 63259  患 抑 郁 症 老 汉 十 几 年 足 不 出 户 身 背 五 四 次 违 章 记 录
# 63260                    一 百 三 十 五 万 九 千 一 百 二 十 三
# 63261                    一 百 三 十 三 万 三 千 五 百 六 十 五
#
#                                        pinyin_underlying  has_sandhi
# 0      guang3 zhou1 nv3 da4 xue2 sheng1 deng1 shan1 s...       False
# 1           zhun1 zhong4 ke1 xue2 gui1 lv4 de5 yao1 qiu2       False
# 2                           qi1 lu4 wu2 ren2 shou4 piao4       False
# 3      hei1 ke4 xuan1 bu4 zhi3 yao4 bo1 da6 mou3 yi2 ...        True
# 4      bei3 jing1 wan4 ke1 zhong3 jing1 li3 liu2 xiao...       False
# ...                                                  ...         ...
# 63257                              qing2 ge1 dui4 chang4       False
# 63258  da4 jia1 shi4 bu2 shi4 hui4 geng4 jing1 xi3 yi...       False
# 63259  huan4 yi4 yu4 zheng4 lao3 han4 shi2 ji3 nian2 ...       False
# 63260  yi4 bai3 san1 shi2 wu3 wan4 jiu3 qian1 yi1 bai...       False
# 63261  yi1 bai3 san1 shi2 san1 wan4 san1 qian1 wu6 ba...        True
#
# [63262 rows x 5 columns]

# %%
df.has_sandhi.mean()
# Out:
# 0.295675128829313

# %% [markdown]
# #### Compute unigram and bigram vocabularies

# %%
vocabulary = Counter(df.pinyin.str.cat(sep=" ").strip().split(" "))
vocabulary.most_common(30)
# Out:
# [('de5', 24707),
#  ('shi4', 15367),
#  ('shi2', 10132),
#  ('you3', 8592),
#  ('yi4', 7129),
#  ('me5', 6579),
#  ('zai4', 6525),
#  ('wo3', 5619),
#  ('yi1', 5425),
#  ('bu4', 5159),
#  ('ren2', 5003),
#  ('shen2', 4888),
#  ('le5', 4801),
#  ('san1', 4782),
#  ('er4', 4763),
#  ('gong1', 4747),
#  ('yi2', 4585),
#  ('zhong1', 4521),
#  ('qi1', 4455),
#  ('ji4', 4396),
#  ('he2', 4285),
#  ('dao4', 4226),
#  ('cheng2', 3928),
#  ('si4', 3893),
#  ('jia1', 3710),
#  ('yuan2', 3689),
#  ('ta1', 3677),
#  ('you2', 3645),
#  ('li4', 3628),
#  ('bai3', 3560)]

# %%
idx2syl = list(vocabulary.keys())
syl2idx = {syl: idx for idx, syl in enumerate(idx2syl)}

# %%
bigrams = np.zeros((len(idx2syl), len(idx2syl)))
for _, row in tqdm(df.iterrows(), total=len(df)):
    toks = row.pinyin.strip().split(" ")
    hanzi_toks = row.text.strip().split(" ")
    for tok1, tok2, hanzi_tok1, hanzi_tok2 in zip(toks, toks[1:], hanzi_toks, hanzi_toks[1:]):
        bigrams[syl2idx[tok1], syl2idx[tok2]] += 1
# Out:
#   0%|          | 0/63262 [00:00<?, ?it/s]

# %%
bigram_df = pd.DataFrame(bigrams)
bigram_df.index = idx2syl
bigram_df.index.name = "tok1"
bigram_df.columns = idx2syl
bigram_df.columns.name = "tok2"
bigram_df = pd.DataFrame(bigram_df.unstack().reset_index(name="count"))
bigram_df
# Out:
#            tok2    tok1  count
# 0        guang3  guang3    0.0
# 1        guang3   zhou1    0.0
# 2        guang3     nv3    0.0
# 3        guang3     da4    0.0
# 4        guang3    xue2    1.0
# ...         ...     ...    ...
# 3400331   cong5  xingr2    0.0
# 3400332   cong5    nan1    0.0
# 3400333   cong5   liur1    0.0
# 3400334   cong5   ning1    0.0
# 3400335   cong5   cong5    0.0
#
# [3400336 rows x 3 columns]

# %%
bigram_df[["tok1_base", "tok1_tone"]] = bigram_df.tok1.str.extract("([^0-9]+)([0-9])")
bigram_df[["tok2_base", "tok2_tone"]] = bigram_df.tok2.str.extract("([^0-9]+)([0-9])")

# %%
bigram_df["tok1_tone"] = bigram_df.tok1_tone.astype(int)
bigram_df["tok2_tone"] = bigram_df.tok2_tone.astype(int)

# %%
bigram_df[(bigram_df.tok2_tone == 3) & (bigram_df.tok1_tone == 3) & (bigram_df["count"] > 0)].sort_values("count")
# Out:
#         tok2    tok1  count tok1_base  tok1_tone tok2_base  tok2_tone
# 533269   yu3  zheng3    1.0     zheng          3        yu          3
# 682468  bao3   chan3    1.0      chan          3       bao          3
# 682487  bao3   wang3    1.0      wang          3       bao          3
# 682511  bao3    zhu3    1.0       zhu          3       bao          3
# 682518  bao3     yi3    1.0        yi          3       bao          3
# ...      ...     ...    ...       ...        ...       ...        ...
# 108853   wu3    bai3   35.0       bai          3        wu          3
# 638081  jiu3    bai3   51.0       bai          3       jiu          3
# 136733  you3     qu3   55.0        qu          3       you          3
# 136507  you3   dian3   61.0      dian          3       you          3
# 137013  you3   ying3  109.0      ying          3       you          3
#
# [1090 rows x 7 columns]

# %% [markdown]
# #### Compute unigram and bigram vocabularies with underlying pinyin

# %%
vocabulary = Counter(df.pinyin_underlying.str.cat(sep=" ").strip().split(" "))
vocabulary.most_common(30)
# Out:
# [('de5', 24707),
#  ('shi4', 15367),
#  ('shi2', 10020),
#  ('you3', 8592),
#  ('yi4', 7129),
#  ('me5', 6579),
#  ('zai4', 6525),
#  ('wo3', 5619),
#  ('yi1', 5425),
#  ('bu4', 5159),
#  ('ren2', 4999),
#  ('shen2', 4857),
#  ('le5', 4801),
#  ('san1', 4782),
#  ('er4', 4763),
#  ('gong1', 4747),
#  ('zhong1', 4521),
#  ('qi1', 4455),
#  ('ji4', 4396),
#  ('he2', 4285),
#  ('yi2', 4228),
#  ('dao4', 4226),
#  ('cheng2', 3928),
#  ('si4', 3893),
#  ('jia1', 3710),
#  ('ta1', 3677),
#  ('yuan2', 3655),
#  ('li4', 3628),
#  ('bai3', 3560),
#  ('xian4', 3531)]

# %%
idx2syl = list(vocabulary.keys())
syl2idx = {syl: idx for idx, syl in enumerate(idx2syl)}

# %%
bigrams = np.zeros((len(idx2syl), len(idx2syl)))
for _, row in tqdm(df.iterrows(), total=len(df)):
    toks = row.pinyin_underlying.strip().split(" ")
    hanzi_toks = row.text.strip().split(" ")
    for tok1, tok2, hanzi_tok1, hanzi_tok2 in zip(toks, toks[1:], hanzi_toks, hanzi_toks[1:]):
        bigrams[syl2idx[tok1], syl2idx[tok2]] += 1
# Out:
#   0%|          | 0/63262 [00:00<?, ?it/s]

# %%
bigram_df = pd.DataFrame(bigrams)
bigram_df.index = idx2syl
bigram_df.index.name = "tok1"
bigram_df.columns = idx2syl
bigram_df.columns.name = "tok2"
bigram_df = pd.DataFrame(bigram_df.unstack().reset_index(name="count"))
bigram_df
# Out:
#            tok2    tok1  count
# 0        guang3  guang3    0.0
# 1        guang3   zhou1    0.0
# 2        guang3     nv3    0.0
# 3        guang3     da4    0.0
# 4        guang3    xue2    1.0
# ...         ...     ...    ...
# 4235359   cong5  xingr2    0.0
# 4235360   cong5    nan1    0.0
# 4235361   cong5   liur1    0.0
# 4235362   cong5   ning1    0.0
# 4235363   cong5   cong5    0.0
#
# [4235364 rows x 3 columns]

# %%
bigram_df
# Out:
#            tok2    tok1  count
# 0        guang3  guang3    0.0
# 1        guang3   zhou1    0.0
# 2        guang3     nv3    0.0
# 3        guang3     da4    0.0
# 4        guang3    xue2    1.0
# ...         ...     ...    ...
# 4235359   cong5  xingr2    0.0
# 4235360   cong5    nan1    0.0
# 4235361   cong5   liur1    0.0
# 4235362   cong5   ning1    0.0
# 4235363   cong5   cong5    0.0
#
# [4235364 rows x 3 columns]

# %%
bigram_df[["tok1_base", "tok1_tone"]] = bigram_df.tok1.str.extract("([^0-9]+)([0-9])")
bigram_df[["tok2_base", "tok2_tone"]] = bigram_df.tok2.str.extract("([^0-9]+)([0-9])")

# %%
bigram_df["tok1_tone"] = bigram_df.tok1_tone.astype(int)
bigram_df["tok2_tone"] = bigram_df.tok2_tone.astype(int)

# %% [markdown]
# ---

# %% [markdown]
# ## Background checks

# %% [markdown]
# ### What are 3-3 instances in the corpus?

# %%
df_33 = df[df.pinyin_underlying.str.contains(r"\w+3 \w+3")]

# %%
HTML("<p>" + "</p><p>".join(df_33.sample(n=10).apply(lambda row: f"<tt>{row.file}</tt><br/>{row.pinyin_underlying}<br/>{row.text}<br/> <audio controls src='intermediates/AISHELL/mfa_input/{row.file[:7]}/{row.file}.wav'></audio>", axis=1)) + "</p>")
# Out:
# <p><tt>SSB15630489</tt><br/>wo6 gan3 jue2 qi2 zhuan3 shou4 jia4 zhi2 hao3 dai3 liao2 shen4 wu2 yu2<br/>我 感 觉 其 转 售 价 值 好 歹 聊 胜 无 于<br/> <audio controls src='intermediates/AISHELL/mfa_input/SSB1563/SSB15630489.wav'></audio></p><p><tt>SSB03410416</tt><br/>ni3 neng2 gao4 su4 wo3 ka3 rui4 na4 zhu4 zai4 nar3 ma5<br/>你 能 告 诉 我 卡 瑞 娜 住 在 哪儿 吗<br/> <audio controls src='intermediates/AISHELL/mfa_input/SSB0341/SSB03410416.wav'></audio></p><p><tt>SSB07800277</tt><br/>ba1 qian1 qi1 bai3 san1 shi2 si4 wan4 liang3 qian1 er4 bai3 wu3 shi2<br/>八 千 七 百 三 十 四 万 两 千 二 百 五 十<br/> <audio controls src='intermediates/AISHELL/mfa_input/SSB0780/SSB07800277.wav'></audio></p><p><tt>SSB07940253</tt><br/>te4 si1 la1 de5 shi4 zhi2 jiang1 suo1 shui3 bai3 fen1 zhi1 ba1 shi2<br/>特 斯 拉 的 市 值 将 缩 水 百 分 之 八 十<br/> <audio controls src='intermediates/AISHELL/mfa_input/SSB0794/SSB07940253.wav'></audio></p><p><tt>SSB03540025</tt><br/>wu3 qing1 jing6 dian3 you3 shen2 me5<br/>武 清 景 点 有 什 么<br/> <audio controls src='intermediates/AISHELL/mfa_input/SSB0354/SSB03540025.wav'></audio></p><p><tt>SSB02410381</tt><br/>lin2 dan1 di4 er4 lun2 heng2 sao3 li3 zong1 wei3<br/>林 丹 第 二 轮 横 扫 李 宗 伟<br/> <audio controls src='intermediates/AISHELL/mfa_input/SSB0241/SSB02410381.wav'></audio></p><p><tt>SSB12530276</tt><br/>zang1 min2 xian4 ren4 zi4 gong4 shi4 xin4 yong4 tou2 zi1 dan1 bao3 you3 xian4 gong1 si1 zong3 jing1 li3<br/>张 民 现 任 自 贡 市 信 用 投 资 担 保 有 限 公 司 总 经 理<br/> <audio controls src='intermediates/AISHELL/mfa_input/SSB1253/SSB12530276.wav'></audio></p><p><tt>SSB07510351</tt><br/>zui4 xin1 qing2 kuang4 shi2 qi1 ren2 chu1 yuan4 si4 ren2 bing4 qing2 ping2 wen3 jiu3 yue4 ba1 ri4<br/>最 新 情 况 十 七 人 出 院 四 人 病 情 平 稳 九 月 八 日<br/> <audio controls src='intermediates/AISHELL/mfa_input/SSB0751/SSB07510351.wav'></audio></p><p><tt>SSB00160225</tt><br/>fo2 luo2 la1 le4 yu2 ci3 zhong3 you2 xi4 hen3 nan2 ji1 nu4 fo2 luo2 la1<br/>弗 罗 拉 乐 于 此 种 游 戏 很 难 激 怒 弗 罗 拉<br/> <audio controls src='intermediates/AISHELL/mfa_input/SSB0016/SSB00160225.wav'></audio></p><p><tt>SSB13660404</tt><br/>wei4 lai2 geng4 duo1 sheng1 zhi2 kong1 jian1 liu2 gei3 mai3 fang2 ren2<br/>未 来 更 多 升 值 空 间 留 给 买 房 人<br/> <audio controls src='intermediates/AISHELL/mfa_input/SSB1366/SSB13660404.wav'></audio></p>

# %% [markdown]
# ## Stimulus search
#
# Find cases of bigrams A+B where B is T3 and either
# 1. A is T2 and there is an attested segmentally identical T3, or
# 2. A is T3 and there is an attested segmentally identical T2

# %% [markdown]
# ### Case 1

# %%
case1_df = bigram_df.loc[(bigram_df["tok1_tone"] == 2) & (bigram_df["tok2_tone"] == 3)]

case1_alternates = bigram_df.set_index(["tok1", "tok2"]).index.intersection(list(zip(case1_df.tok1.str.replace("2", "6"), case1_df.tok2)))
case1_alternates = bigram_df.set_index(["tok1", "tok2"]).loc[case1_alternates]

case1_df = pd.merge(case1_df, case1_alternates[["count", "tok1_base"]].reset_index(),
                    how="inner", left_on=["tok1_base", "tok2"], right_on=["tok1_base", "tok2"],
                    suffixes=("", "_alternate"))
case1_df["count_mean"] = (case1_df["count"] + case1_df.count_alternate) / 2
case1_df["count_ratio"] = case1_df["count"] / (case1_df["count_alternate"] + 1e-4)
case1_df
# Out:
#          tok2   tok1  count tok1_base  tok1_tone tok2_base  tok2_tone  \
# 0      guang3   xue2    1.0       xue          2     guang          3
# 1      guang3  lian2    0.0      lian          2     guang          3
# 2      guang3    yi2    0.0        yi          2     guang          3
# 3      guang3   qiu2    0.0       qiu          2     guang          3
# 4      guang3    wu2    0.0        wu          2     guang          3
# ...       ...    ...    ...       ...        ...       ...        ...
# 81743   huai3    ku2    0.0        ku          2      huai          3
# 81744   huai3  ruan2    0.0      ruan          2      huai          3
# 81745   huai3  gang2    0.0      gang          2      huai          3
# 81746   huai3   tui2    0.0       tui          2      huai          3
# 81747   huai3  juan2    0.0      juan          2      huai          3
#
#       tok1_alternate  count_alternate  count_mean  count_ratio
# 0               xue6              0.0         0.5      10000.0
# 1              lian6              0.0         0.0          0.0
# 2                yi6              0.0         0.0          0.0
# 3               qiu6              0.0         0.0          0.0
# 4                wu6              0.0         0.0          0.0
# ...              ...              ...         ...          ...
# 81743            ku6              0.0         0.0          0.0
# 81744          ruan6              0.0         0.0          0.0
# 81745          gang6              0.0         0.0          0.0
# 81746           tui6              0.0         0.0          0.0
# 81747          juan6              0.0         0.0          0.0
#
# [81748 rows x 11 columns]

# %%
# case1_df[case1_df.count_ratio.between(1/4, 4)].sort_values("count_mean", ascending=False).head(50)

# %% [markdown]
# ### Case 2

# %%
case2_df = bigram_df.loc[(bigram_df["tok1_tone"] == 6) & (bigram_df["tok2_tone"] == 3)]

case2_alternates = bigram_df.set_index(["tok1", "tok2"]).index.intersection(list(zip(case1_df.tok1.str.replace("6", "2"), case1_df.tok2)))
case2_alternates = bigram_df.set_index(["tok1", "tok2"]).loc[case2_alternates]

case2_df = pd.merge(case2_df, case2_alternates[["count", "tok1_base"]].reset_index(),
                    how="inner", left_on=["tok1_base", "tok2"], right_on=["tok1_base", "tok2"],
                    suffixes=("", "_alternate"))
case2_df["count_mean"] = (case2_df["count"] + case2_df.count_alternate) / 2
case2_df["count_ratio"] = case2_df["count"] / (case2_df["count_alternate"] + 1e-4)
case2_df
# Out:
#          tok2   tok1  count tok1_base  tok1_tone tok2_base  tok2_tone  \
# 0      guang3    da6    0.0        da          6     guang          3
# 1      guang3    wu6    0.0        wu          6     guang          3
# 2      guang3    si6    0.0        si          6     guang          3
# 3      guang3   tie6    0.0       tie          6     guang          3
# 4      guang3   bai6    0.0       bai          6     guang          3
# ...       ...    ...    ...       ...        ...       ...        ...
# 81743   huai3    mo6    0.0        mo          6      huai          3
# 81744   huai3   tan6    0.0       tan          6      huai          3
# 81745   huai3  zhai6    0.0      zhai          6      huai          3
# 81746   huai3  luan6    0.0      luan          6      huai          3
# 81747   huai3  tian6    0.0      tian          6      huai          3
#
#       tok1_alternate  count_alternate  count_mean  count_ratio
# 0                da2              1.0         0.5          0.0
# 1                wu2              0.0         0.0          0.0
# 2                si2              0.0         0.0          0.0
# 3               tie2              0.0         0.0          0.0
# 4               bai2              0.0         0.0          0.0
# ...              ...              ...         ...          ...
# 81743            mo2              0.0         0.0          0.0
# 81744           tan2              0.0         0.0          0.0
# 81745          zhai2              0.0         0.0          0.0
# 81746          luan2              0.0         0.0          0.0
# 81747          tian2              0.0         0.0          0.0
#
# [81748 rows x 11 columns]

# %%
# case2_df[case2_df.count_ratio.between(1/4, 4)].sort_values("count_mean", ascending=False).head(50)

# %% [markdown]
# ## Play

# %%
aligned_df = pd.read_csv("intermediates/AISHELL/words_aligned.csv").set_index(["file", "word_idx"])
# Drop sentence-initial, sentence-final silence; renumber word idxs
aligned_df = aligned_df[~aligned_df.text.isna()]
aligned_df.index.set_names("drop", level="word_idx", inplace=True)
aligned_df["word_idx"] = aligned_df.groupby("file").cumcount()
aligned_df = aligned_df.reset_index("drop").set_index("word_idx", append=True)
aligned_df
# Out:
#                       drop  start  stop text
# file        word_idx
# SSB11250133 0            1   0.28  0.46    澳
#             1            2   0.46  0.59    大
#             2            3   0.59  0.98    利
#             3            4   0.98  1.07    亚
#             4            5   1.07  1.18    门
# ...                    ...    ...   ...  ...
# SSB11610110 16          21   5.90  6.10    赛
#             17          22   6.10  6.22    一
#             18          23   6.22  6.64    举
#             19          24   6.64  6.88    得
#             20          25   6.88  7.22    冠
#
# [737816 rows x 4 columns]

# %%
# Check that sentence lengths agree
counts_from_aligned = aligned_df.groupby("file").size()
counts_from_df = df.set_index("file").text.str.count(" ") + 1
assert (counts_from_aligned == counts_from_df).all(), "Count mismatches between two data annotations"

# %%
show = case1_df[case1_df.count_ratio.between(1/4, 4)].sort_values("count_mean", ascending=False)
# show = case2_df[case2_df.count_ratio.between(1/4, 4)].sort_values("count_mean", ascending=False).head(5)
rendered = []

sentences_per_item = 5
render_items = 2

item_df = []

# For the given bigram item, extract specific sentences + audio clips
for i, (_, row) in enumerate(tqdm(show.iterrows(), total=len(show))):
    show_i_left = df[df.pinyin_underlying.str.contains(f"{row.tok1} {row.tok2}")].head(sentences_per_item)
    show_i_right = df[df.pinyin_underlying.str.contains(f"{row.tok1_alternate} {row.tok2}")].head(sentences_per_item)
    
    if len(show_i_left) == 0 or len(show_i_right) == 0:
        continue
        
    def prepare_instance(instance_row, tok1, tok2):
        item_start_char = instance_row.pinyin_underlying.index(f"{tok1} {tok2}")
        item_end_char = item_start_char + len(f"{tok1} {tok2}")
        item_start_idx = instance_row.pinyin_underlying[:item_start_char].count(" ")
        item_end_idx = instance_row.pinyin_underlying[:item_end_char].count(" ") + 1
        hanzi_toks = instance_row.text.split(" ")

        # Compute metadata
        preceding_syllable_forms_word = item_start_idx > 0 and ''.join(hanzi_toks[item_start_idx - 1:item_start_idx + 1]) in cedict

        # Retrieve alignment data
        item_aligned = aligned_df.loc[instance_row.file]
        
        # Retrieve containing file
        speaker_id = instance_row.file[:7]
        sound_path = f"intermediates/AISHELL/mfa_input/{speaker_id}/{instance_row.file}.wav"
        sound = pydub.AudioSegment.from_wav(sound_path)
        # Slice sound
        buffer_size = 1 # buffer size in seconds
        slice_onset = int(max(0, item_aligned.iloc[item_start_idx].start - buffer_size) * 1000)
        slice_offset = int((item_aligned.iloc[item_end_idx - 1].stop + buffer_size) * 1000)
        sound_sliced = sound[slice_onset:slice_offset]
        sound_file = f"intermediates/AISHELL/render/{instance_row.file}_{row.tok1_base}{row.tok2}.wav"
        sound_sliced.export(f"{sound_file}", format="wav")

        return {
            "file": instance_row.file,
            "hanzi": " ".join(hanzi_toks),
            "pinyin": instance_row.pinyin,
            "pinyin_underlying": instance_row.pinyin_underlying,
            "tok1": tok1,
            "tok2": tok2,
            "start_token_idx": item_start_idx,
            "end_token_idx": item_end_idx,
            "start_time": item_aligned.iloc[item_start_idx].start,
            "end_time": item_aligned.iloc[item_end_idx - 1].stop,

            "preceding_syllable_forms_word": preceding_syllable_forms_word,
            
            "slice_start": slice_onset,
            "slice_end": slice_offset,
            "slice_file": sound_file,
        }

    def render_instance(info):
        # Render text
        html_toks = info["hanzi"].split(" ")
        for idx in range(info["start_token_idx"], info["end_token_idx"]):
            html_toks[idx] = f"<strong>{html_toks[idx]}</strong>"
        if info["preceding_syllable_forms_word"]:
            for idx in range(info["start_token_idx"] - 1, info["start_token_idx"] + 1):
                html_toks[idx] = f"<span style='color: red'>{html_toks[idx]}</span>"
        pinyin = info["pinyin_underlying"].replace(f"{info['tok1']} {info['tok2']}", f"<strong>{info['tok1']} {info['tok2']}</strong>")
        
        return f"<tr><td style='font-family: monospace; font-size: 75%'>" + \
               f"{info['file']} <audio controls src='{info['slice_file']}'></audio></td>" + \
               f"<td><p>{''.join(html_toks)}<br/><small>{pinyin}</small></p></td></tr>"

    left_data = [prepare_instance(item, row.tok1, row.tok2) for _, item in show_i_left.iterrows()]
    right_data = [prepare_instance(item, row.tok1_alternate, row.tok2) for _, item in show_i_right.iterrows()]

    data = pd.concat([pd.DataFrame.from_records(left_data), pd.DataFrame.from_records(right_data)],
                     names=["case"], keys=[2, 6])
    item_df.append(data)
    
    if i < render_items:
        left_rendered = [render_instance(data_i) for data_i in left_data]
        right_rendered = [render_instance(data_i) for data_i in right_data]
        
        left_rendered = "<table>" + "".join(left_rendered) + "</table>"
        right_rendered = "<table>" + "".join(right_rendered) + "</table>"
        
        rendered.append(f"<tr><th colspan='2' style='text-align: center'>{row.tok1_base} {row.tok2}<br/><span style='font-weight: normal'>T6 T3: {row['count']}; T2 T3: {row.count_alternate}</span></th></tr>"
                        f"<tr><td>{left_rendered}</td><td>{right_rendered}</td></tr>")

HTML("<table>" + "".join(rendered) + "</table>")

# Presentation conditions

# Single syllable
# S: guo6
# Q: guo6 vs guo2

# A+B syllables
# S: guo6 you3
# Q: guo6 vs guo2

# A+B+right context (is this worth anything??)
# S: guo6 you3 shen2 me5
# Q: guo6 vs guo2

# Left context+A+B+Right context
# S: gan1 su4 de5 shui6 guo6 you3 shen2 me5
# Q: guo6 vs guo2

# Ways of accounting for bigram

# Add left context up to containing constituent of A/A+B
# Maybe easier to code: add left characters s.t. left context + A forms a word in the lexicon
# S: shui6 guo6 you3 shen2 me5
# Q: ..

# ----

# Variables to code in the df for controls and/or augmented designs:
# - do A+B form a word? (check lexicon)
# - do (A-1) + A form a word? (check lexicon)
# Out:
#   0%|          | 0/512 [00:00<?, ?it/s]
# <table><tr><th colspan='2' style='text-align: center'>guo you3<br/><span style='font-weight: normal'>T6 T3: 27.0; T2 T3: 17.0</span></th></tr><tr><td><table><tr><td style='font-family: monospace; font-size: 75%'>SSB00090085 <audio controls src='intermediates/AISHELL/render/SSB00090085_guoyou3.wav'></audio></td><td><p>文明<span style='color: red'>帝</span><span style='color: red'><strong>国</strong></span><strong>有</strong>什么<br/><small>wen2 ming2 di4 <strong>guo2 you3</strong> shen2 me5</small></p></td></tr><tr><td style='font-family: monospace; font-size: 75%'>SSB00330050 <audio controls src='intermediates/AISHELL/render/SSB00330050_guoyou3.wav'></audio></td><td><p><strong>国</strong><strong>有</strong>独资类医院有什么<br/><small><strong>guo2 you3</strong> du2 zi1 lei4 yi1 yuan4 you3 shen2 me5</small></p></td></tr><tr><td style='font-family: monospace; font-size: 75%'>SSB03390017 <audio controls src='intermediates/AISHELL/render/SSB03390017_guoyou3.wav'></audio></td><td><p>他描述其公司为<strong>国</strong><strong>有</strong>的国际化公司<br/><small>ta1 miao2 shu4 qi2 gong1 si1 wei4 <strong>guo2 you3</strong> de5 guo2 ji4 hua4 gong1 si1</small></p></td></tr><tr><td style='font-family: monospace; font-size: 75%'>SSB03800333 <audio controls src='intermediates/AISHELL/render/SSB03800333_guoyou3.wav'></audio></td><td><p>东芝<span style='color: red'>中</span><span style='color: red'><strong>国</strong></span><strong>有</strong>限公司公关宣传部对记者表示<br/><small>dong1 zhi1 zhong1 <strong>guo2 you3</strong> xian4 gong1 si1 gong1 guan1 xuan1 chuan2 bu4 dui4 ji4 zhe6 biao3 shi4</small></p></td></tr><tr><td style='font-family: monospace; font-size: 75%'>SSB04260384 <audio controls src='intermediates/AISHELL/render/SSB04260384_guoyou3.wav'></audio></td><td><p>连续有<strong>国</strong><strong>有</strong>和民营资本投资设立保险公司<br/><small>lian2 xu4 you3 <strong>guo2 you3</strong> he2 min2 ying2 zi1 ben3 tou2 zi1 she4 li4 bao6 xian3 gong1 si1</small></p></td></tr></table></td><td><table><tr><td style='font-family: monospace; font-size: 75%'>SSB00330082 <audio controls src='intermediates/AISHELL/render/SSB00330082_guoyou3.wav'></audio></td><td><p>甘肃的<span style='color: red'>水</span><span style='color: red'><strong>果</strong></span><strong>有</strong>什么<br/><small>gan1 su4 de5 shui6 <strong>guo6 you3</strong> shen2 me5</small></p></td></tr><tr><td style='font-family: monospace; font-size: 75%'>SSB00570108 <audio controls src='intermediates/AISHELL/render/SSB00570108_guoyou3.wav'></audio></td><td><p>目前大中华区<span style='color: red'>苹</span><span style='color: red'><strong>果</strong></span><strong>有</strong>一家直营店<br/><small>mu4 qian2 da4 zhong1 hua2 qu1 ping2 <strong>guo6 you3</strong> yi4 jia1 zhi2 ying2 dian4</small></p></td></tr><tr><td style='font-family: monospace; font-size: 75%'>SSB00730128 <audio controls src='intermediates/AISHELL/render/SSB00730128_guoyou3.wav'></audio></td><td><p>其中样本检测<span style='color: red'>结</span><span style='color: red'><strong>果</strong></span><strong>有</strong>疑问的运动员多达八百人<br/><small>qi2 zhong1 yang4 ben6 jian3 ce4 jie2 <strong>guo6 you3</strong> yi2 wen4 de5 yun4 dong4 yuan2 duo1 da2 ba1 bai3 ren2</small></p></td></tr><tr><td style='font-family: monospace; font-size: 75%'>SSB02000391 <audio controls src='intermediates/AISHELL/render/SSB02000391_guoyou3.wav'></audio></td><td><p><span style='color: red'>如</span><span style='color: red'><strong>果</strong></span><strong>有</strong>更多的开发商参与进来<br/><small>ru2 <strong>guo6 you3</strong> geng4 duo1 de5 kai1 fa1 shang1 can1 yu4 jin4 lai2</small></p></td></tr><tr><td style='font-family: monospace; font-size: 75%'>SSB03930398 <audio controls src='intermediates/AISHELL/render/SSB03930398_guoyou3.wav'></audio></td><td><p><span style='color: red'>如</span><span style='color: red'><strong>果</strong></span><strong>有</strong>人理解的话<br/><small>ru2 <strong>guo6 you3</strong> ren2 li6 jie3 de5 hua4</small></p></td></tr></table></td></tr><tr><th colspan='2' style='text-align: center'>guo shou3<br/><span style='font-weight: normal'>T6 T3: 15.0; T ...

# %%
len(case1_df[(case1_df["count"] > 2) & (case1_df["count_alternate"] > 2)])
# Out:
# 68

# %%
case1_df[(case1_df["count"] > 2) & (case1_df["count_alternate"] > 2)]
# Out:
#         tok2    tok1  count tok1_base  tok1_tone tok2_base  tok2_tone  \
# 858     zhi3     yi2    7.0        yi          2       zhi          3
# 866     zhi3    wei2   13.0       wei          2       zhi          3
# 1296    bei3     yu2    8.0        yu          2       bei          3
# 1724     li3     yu2    3.0        yu          2        li          3
# 2366    bai3     yu2    8.0        yu          2       bai          3
# ...      ...     ...    ...       ...        ...       ...        ...
# 25979  shui3     li2    3.0        li          2      shui          3
# 26340    si3  chang2    3.0     chang          2        si          3
# 30409   cai3     fu2    8.0        fu          2       cai          3
# 30829   hao3    mei2    3.0       mei          2       hao          3
# 30830   hao3    zhi2    3.0       zhi          2       hao          3
#
#       tok1_alternate  count_alternate  count_mean  count_ratio
# 858              yi6              3.0         5.0     2.333256
# 866             wei6              5.0         9.0     2.599948
# 1296             yu6              4.0         6.0     1.999950
# 1724             yu6              3.0         3.0     0.999967
# 2366             yu6              3.0         5.5     2.666578
# ...              ...              ...         ...          ...
# 25979            li6              4.0         3.5     0.749981
# 26340         chang6              3.0         3.0     0.999967
# 30409            fu6              3.0         5.5     2.666578
# 30829           mei6             19.0        11.0     0.157894
# 30830           zhi6              3.0         3.0     0.999967
#
# [68 rows x 11 columns]

# %%
item_df = pd.concat(item_df)
item_df
# Out:
#                file                                         hanzi  \
# case
# 2    0  SSB00090085                                 文 明 帝 国 有 什 么
#      1  SSB00330050                           国 有 独 资 类 医 院 有 什 么
#      2  SSB03390017                 他 描 述 其 公 司 为 国 有 的 国 际 化 公 司
#      3  SSB03800333           东 芝 中 国 有 限 公 司 公 关 宣 传 部 对 记 者 表 示
#      4  SSB04260384           连 续 有 国 有 和 民 营 资 本 投 资 设 立 保 险 公 司
# ...             ...                                           ...
# 6    0  SSB05440080             可 我 们 通 过 晨 跑 却 让 生 理 机 能 永 葆 青 春
# 2    0  SSB04270377  其 中 三 水 上 月 新 建 住 宅 成 交 套 数儿 环 比 增 幅 五 区 第 一
# 6    0  SSB11250489                           金 府 五 金 机 电 城 金 府 路
# 2    0  SSB01450418         娱 乐 节 目 昨 日 暂 停 五 天 抗 战 剧 避 免 手 撕 鬼 子
# 6    0  SSB07460014                                 潜 艇 武 器 有 什 么
#
#                                                    pinyin  \
# case
# 2    0                 wen2 ming2 di4 guo2 you3 shen2 me5
#      1    guo2 you3 du2 zi1 lei4 yi1 yuan4 you3 shen2 me5
#      2  ta1 miao2 shu4 qi2 gong1 si1 wei4 guo2 you3 de...
#      3  dong1 zhi1 zhong1 guo2 you3 xian4 gong1 si1 go...
#      4  lian2 xu4 you3 guo2 you3 he2 min2 ying2 zi1 be...
# ...                                                   ...
# 6    0  ke2 wo3 men5 tong1 guo4 chen2 pao3 que4 rang4 ...
# 2    0  qi2 zhong1 san1 shui3 shang4 yue4 xin1 jian4 z...
# 6    0    jin1 fu2 wu3 jin1 ji1 dian4 cheng2 jin1 fu3 lu4
# 2    0  yu2 le4 jie2 mu4 zuo2 ri4 zan4 ting2 wu3 tian1...
# 6    0                 qian2 ting2 wu3 qi4 you3 shen2 me5
#
#                                         pinyin_underlying   tok1  tok2  \
# case
# 2    0                 wen2 ming2 di4 guo2 you3 shen2 me5   guo2  you3
#      1    guo2 you3 du2 zi1 lei4 yi1 yuan4 you3 shen2 me5   guo2  you3
#      2  ta1 miao2 shu4 qi2 gong1 si1 wei4 guo2 you3 de...   guo2  you3
#      3  dong1 zhi1 zhong1 guo2 you3 xian4 gong1 si1 go...   guo2  you3
#      4  lian2 xu4 you3 guo2 you3 he2 min2 ying2 zi1 be...   guo2  you3
# ...                                                   ...    ...   ...
# 6    0  ke6 wo3 men5 tong1 guo4 chen2 pao3 que4 rang4 ...  yong6  bao3
# 2    0  qi2 zhong1 san1 shui3 shang4 yue4 xin1 jian4 z...    fu2   wu3
# 6    0    jin1 fu6 wu3 jin1 ji1 dian4 cheng2 jin1 fu3 lu4    fu6   wu3
# 2    0  yu2 le4 jie2 mu4 zuo2 ri4 zan4 ting2 wu3 tian1...  ting2   wu3
# 6    0                 qian2 ting6 wu3 qi4 you3 shen2 me5  ting6   wu3
#
#         start_token_idx  end_token_idx  start_time  end_time  \
# case
# 2    0                3              5        0.93      1.21
#      1                0              2        0.26      0.86
#      2                7              9        1.60      1.91
#      3                3              5        0.84      1.21
#      4                3              5        1.28      1.64
# ...                 ...            ...         ...       ...
# 6    0               13             15        2.60      2.92
# 2    0               17             19        4.41      4.68
# 6    0                1              3        0.43      0.87
# 2    0                7              9        1.76      2.51
# 6    0                1              3        0.37      0.45
#
#         preceding_syllable_forms_word  slice_start  slice_end  \
# case
# 2    0                           True            0       2210
#      1                          False            0       1859
#      2                          False          600       2910
#      3                           True            0       2210
#      4                          False          280       2639
# ...                               ...          ...        ...
# 6    0                          False         1600       3920
# 2    0                           True         3410       5680
# 6    0                          False            0       1870
# 2    0                           True          760       3510
# 6    0                           True            0       1450
#
#                                                slice_file
# case
# 2    0  intermediates/AISHELL/render/SSB00090085_guoyo...
#      1  intermediates/AISHELL/render/SSB00330050_guoyo...
#      2  intermediates/AISHELL/render/SSB03390017_guoyo...
#      3  intermediates/AISHELL/render/SSB03800333_guoyo...
#      4  intermediates/AISHELL/render/SSB04260384_guoyo...
# ...                                                   ...
# 6    0  intermediates/AISHELL/render/SSB05440080_yongb...
# 2    0  intermediates/AISHELL/render/SSB04270377_fuwu3...
# 6    0  intermediates/AISHELL/render/SSB11250489_fuwu3...
# 2    0  intermediates/AISHELL/render/SSB01450418_tingw...
# 6    0  intermediates/AISHELL/render/SSB07460014_tingw...
#
# [1880 rows x 14 columns]

# %%
item_df.to_csv("intermediates/AISHELL/item_df.csv")
